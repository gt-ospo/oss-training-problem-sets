# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel $\rightarrow$ Restart) and then **run all cells** (in the menubar, select Cell $\rightarrow$ Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # Problem Set for L08: Licensing

# %% [markdown]
# When it comes to open source software, it is important to distinguish between specific permissive and copyleft licenses. Answer some of the following questions about some differences in the application of various licenses. If *multiple* answers are correct (there will always be between 1 and 4 correct answers inclusive), separate answers with a comma in between. Use the letters associated with the answer to denote selection on the line **after**: `%%writefile -a ps08_student_answers.txt`. Answers should look like `A, B` if there are multiple answers or just `A` for one answer, ordering does not matter. Please reference the source in `L08 - Licensing`.

# %%
from pathlib import Path
from check_helper import changeDirectory
assignmentPath = Path.home() / "PS_OSPO"
# assignmentPath = Path.cwd() # Instructor Testing Use Only
changeDirectory(assignmentPath)

# %%
# %%writefile ps08_student_answers.txt
# Student Solutions:

# %% [markdown]
# #### 1. Which of the following licenses incorporate some form of copyleft?
# A. MIT
# B. LGPLv3
# C. BSD 3-clause
# D. Apache 2.0
# E. GPLv2

# %%
# %%writefile -a ps08_student_answers.txt
# # YOUR CODE HERE
# raise NotImplementedError()

# %% [markdown]
# #### 2. Which statement(s) describe the key freedoms granted by the MIT license?
#
# A. Users may modify and redistribute the software with minimal obligations.
# B. Redistributions must be licensed under a copyleft license.
# C. Commercial closed‑source use is allowed.
# D. Attribution is required.
# E. Source code of derivative works must be released under a MIT/BSD license.

# %%
# %%writefile -a ps08_student_answers.txt
# # YOUR CODE HERE
# raise NotImplementedError()

# %% [markdown]
# #### 3. Which of the following statement(s) correctly describes differences among the BSD 2‑Clause and BSD 3‑Clause licenses?
#
# A. The BSD 2‑Clause license prohibits commercial use unless explicit permission is granted.
# B. The BSD 3‑Clause license adds a non‑endorsement clause not found in the 2‑Clause version.
# C. The BSD 3‑Clause license allows proprietary redistribution without open‑sourcing derivative works.

# %%
# %%writefile -a ps08_student_answers.txt
# # YOUR CODE HERE
# raise NotImplementedError()

# %% [markdown]
# #### 4. Which statement(s) describe differences between BSD 3‑Clause and Apache 2.0?
#
# A. Apache 2.0 includes explicit patent protections.
# B. Apache 2.0 requires stating modified files.
# C. BSD 3‑Clause has a non‑endorsement clause.
# D. BSD 3‑Clause allows proprietary use only with disclosure requirements.
# E. BSD 3‑Clause requires copyleft sharing of derivative works.

# %%
# %%writefile -a ps08_student_answers.txt
# # YOUR CODE HERE
# raise NotImplementedError()

# %% [markdown]
# #### 5. The Apache 2.0 license includes a patent grant. Since licenses may be compatible with one another, which licenses can have Apache 2.0 added to it (but not necessarily the other way around)?
#
# A. MIT
# B. BSD 3-clause
# C. LGPLv3
# D. GPLv2
# E. GPLv3

# %%
# %%writefile -a ps08_student_answers.txt
# # YOUR CODE HERE
# raise NotImplementedError()

# %% [markdown]
# #### 6. If you create a library licensed under LGPLv3, to what extent can the author of a proprietary app modify, then utilize your code and why? Additionally, what can you and other contributors do to prevent proprietary apps from utilizing *future* versions? Assume simple attribution includes notices, licenses, and possibly source code.
#
# A. The author can statically link your library with simple attribution. There is nothing you can do to to prevent future usage.
# B. The author can statically link your library with simple attribution. Upgrade the license to GPLv2.
# C. The author can dynamically link your library with simple attribution. There is nothing you can do to to prevent future usage.
# D. The author can dynamically link your library with simple attribution. Upgrade the license to GPLv2.
# E. The author can dynamically link your library with simple attribution. Upgrade the license to GPLv3.

# %%
# %%writefile -a ps08_student_answers.txt
# # YOUR CODE HERE
# raise NotImplementedError()

# %% [markdown]
# #### 7. List the *true* statements about LGPLv3 and GPLv2:
#
# A. LGPLv3 licensing allows for unmodified usage of the an OSS library in proprietary software
# B. LGPLv3 licensing requires object files to be provided when statically linked
# C. GPLv2 licensing gives patent protection for an OSS codebase
# D. GPLv2 licensing prevents other programs from releasing their code under any other license
# E. There are no significant differences besides semantics between the two licenses

# %%
# %%writefile -a ps08_student_answers.txt
# # YOUR CODE HERE
# raise NotImplementedError()

# %% [markdown]
# #### 8. Which of the following accurately compares GPLv2 and GPLv3 in relation to each other?
#
# A. GPLv2 includes network‑use requirements
# B. GPLv2 is compatible with Apache License 2.0
# C. GPLv3 includes explicit patent protections
# D. GPLv3 prohibits hardware‑locked binary execution
# E. GPLv2 and GPLv3 are mutually compatible

# %%
# %%writefile -a ps08_student_answers.txt
# # YOUR CODE HERE
# raise NotImplementedError()

# %% [markdown]
# #### 9. Under AGPL, which scenario triggers the obligation to provide source code?
#
# A. Running modified software on a personal computer.
# B. Selling boxed copies of the software.
# C. Allowing others to interact with the modified program over a network.
# D. Using software internally within a company with outside access.
# E. Storing the software on a cloud server without user interaction.

# %%
# %%writefile -a ps08_student_answers.txt
# # YOUR CODE HERE
# raise NotImplementedError()

# %% [markdown]
# #### 10. Which of the following actions are *required* by various OSS licenses (assuming non-public domain)?
#
# A. Include original license text and copyright *notice* when redistributing.
# B. Publish any modifications to the source code when using software under copyleft licenses.
# C. Publish all source code when distributing a derivative work of a LGPL licensed project.
# D. Provide written attribution to the original authors.
# E. Releasing derivative works under the same license for all copyleft licenses.

# %%
# %%writefile -a ps08_student_answers.txt
# # YOUR CODE HERE
# raise NotImplementedError()

# %% [markdown]
# Make sure to validate your submission to see if `ps08_student_answers.txt` has the desired answers in order.

# %%
# Tests - Hidden
