# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel $\rightarrow$ Restart) and then **run all cells** (in the menubar, select Cell $\rightarrow$ Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # `PS_OSPO` README
#
# > **Do not change the name of this folder!**
#
# For general instructions on operating JupyterHub and NbGrader, see [`gt-ospo/nbgrader-server-config`](https://github.com/gt-ospo/nbgrader-server-config). Read `Quickstart.md` and `Student.md`.
#
# The following problem sets cover the content in `L01`, `L03`, `L04`, and `L08` respectively. Some test cases are shown and some are hidden, usually denoted by code cells with comment blocks. These test cases are nearly identical in style to the ones in `Modules_OSPO` (`L01`-`L04`). If you have questions, please message in discord. See the `Modules_OSPO` assignment for necessary references.
#
# ***Remember to submit this assignment using `Assignment list` or `nbgrader submit PS_OSPO --course BashMD`***
