# %% [markdown]
# # `PS_OSPO` README
#
# > **Do not rename this folder!**
#
# For general instructions on operating JupyterHub and NbGrader, see [`gt-ospo/oss-training-problem-sets`](https://github.com/gt-ospo/oss-training-problem-sets). Read `Student_Instructions.md`.
#
# The following problem sets cover the content in `L01`, `L02`, `L04`, `L05`, and `L10` (intersect-training) respectively. Some test cases are shown and some are hidden, usually denoted by code cells with comment blocks. These test cases are nearly identical in style to the ones in `Modules_OSPO` (`L02`-`L04`). If you have questions, please message in discord. See the `Modules_OSPO` assignment for necessary references.
#
# ***Remember to submit this assignment using `Assignment list` or `nbgrader submit PS_OSPO --course BashMD`***
